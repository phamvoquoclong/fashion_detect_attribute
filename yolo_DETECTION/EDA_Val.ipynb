# %%
import json

with open(r"D:\test\instances_attributes_val2020.json", "r") as f:
    data = json.load(f)

print(type(data))
print(data.keys())
# Out:
# <class 'dict'>
# dict_keys(['info', 'categories', 'attributes', 'licenses', 'annotations', 'images'])

# %%
images = data["images"]
num_images = len(images)
print("Total images:", num_images)
# Out:
# Total images: 1158

# %%
import os

image_dir = r"D:\test\images\val"  # đổi thành đường dẫn thư mục ảnh của bạn

# chỉ lấy file ảnh phổ biến
valid_exts = (".jpg", ".jpeg", ".png")

files_in_dir = [
    f for f in os.listdir(image_dir)
    if f.lower().endswith(valid_exts)
]

print("Total images in folder:", len(files_in_dir))

images = data["images"]

json_filenames = [img["file_name"] for img in images]

print("Total images in JSON:", len(json_filenames))
# Out:
# Total images in folder: 1158
# Total images in JSON: 1158

# %%
set_dir = set(files_in_dir)
set_json = set(json_filenames)
common_images = set_dir & set_json
print("Images present in BOTH folder and JSON:", len(common_images))
# Out:
# Images present in BOTH folder and JSON: 1158

# %%
image_filenames = [img["file_name"] for img in images]

print(image_filenames[:10])  # xem thử 10 file đầu
# Out:
# ['e14733841b04c64e75789a91fbe549b3.jpg', 'b4f6d9c2696573ff0cfc05070d17b5b6.jpg', '8075d3afc3d574f8cfd7c5400417d9fc.jpg', '32e566cd7c0388f44f1a09e10e2ac96c.jpg', '0229bef01efc25f915374d55f59cbfdd.jpg', '5c0eaf59c2eaf693980708f24a6b818a.jpg', '90b68fc59a4b48dad4be10eeaef7205f.jpg', '7fc8a54146a81b33f348f21ad07fa141.jpg', 'db754979155507a6528eeb152a0adaf9.jpg', 'ecb9073d265f18598c61f21d10098339.jpg']

# %%
categories = data["categories"]
category_names = [cat["name"] for cat in categories]

print(len(category_names))
# Out:
# 46

# %%
categories = data["attributes"]
category_names = [cat["name"] for cat in categories]

print(len(category_names))
# Out:
# 294

# %%
annotations = data["annotations"]
empty_attr_count = sum(
    1 for ann in annotations
    if not ann.get("attribute_ids")
)
total_annotations = len(annotations)
empty_attr_count, total_annotations
# Out:
# (3522, 8781)

# %%
ratio = empty_attr_count / total_annotations * 100

print(f"Empty attribute annotations: {empty_attr_count}/{total_annotations} ({ratio:.2f}%)")
# Out:
# Empty attribute annotations: 3522/8781 (40.11%)

# %%
categories = data["categories"]

def clean_name(name):
    return name.split("(")[0].strip()

cat_id2name = {
    cat["id"]: clean_name(cat["name"])
    for cat in categories
}

# %%
from collections import defaultdict

annotations = data["annotations"]

stats = defaultdict(lambda: {
    "total": 0,
    "with_attr": 0,
    "empty_attr": 0
})

for ann in annotations:
    cid = ann["category_id"]
    stats[cid]["total"] += 1

    if ann.get("attribute_ids"):
        stats[cid]["with_attr"] += 1
    else:
        stats[cid]["empty_attr"] += 1

# %%
results = []

for cid, s in stats.items():
    total = s["total"]
    with_attr = s["with_attr"]
    empty_attr = s["empty_attr"]

    ratio = with_attr / total * 100 if total > 0 else 0

    results.append({
        "category_id": cid,
        "category_name": cat_id2name.get(cid, str(cid)),
        "total": total,
        "with_attr": with_attr,
        "empty_attr": empty_attr,
        "attr_ratio": ratio
    })

# %%
results_sorted = sorted(
    results,
    key=lambda x: x["attr_ratio"])

for r in results_sorted[:25]:
    print(
        f'{r["category_name"]}: '
        f'{r["with_attr"]}/{r["total"]} '
        f'({r["attr_ratio"]:.1f}%)'
    )
# Out:
# scarf: 0/48 (0.0%)
# hood: 0/32 (0.0%)
# bag, wallet: 0/214 (0.0%)
# glove: 0/31 (0.0%)
# hat: 0/74 (0.0%)
# shoe: 0/1566 (0.0%)
# glasses: 0/130 (0.0%)
# sock: 0/87 (0.0%)
# headband, head covering, hair accessory: 0/109 (0.0%)
# watch: 0/84 (0.0%)
# belt: 0/164 (0.0%)
# tights, stockings: 0/122 (0.0%)
# epaulette: 0/14 (0.0%)
# flower: 0/37 (0.0%)
# bead: 0/107 (0.0%)
# leg warmer: 0/14 (0.0%)
# buckle: 0/67 (0.0%)
# bow: 0/6 (0.0%)
# rivet: 0/143 (0.0%)
# umbrella: 0/5 (0.0%)
# ribbon: 0/9 (0.0%)
# applique: 0/61 (0.0%)
# fringe: 0/30 (0.0%)
# tassel: 0/39 (0.0%)
# tie: 0/3 (0.0%)
